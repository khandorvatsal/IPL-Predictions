# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# # Dataset 1 without Multiplying Innings

# %% [markdown]
# ## Dataset 1- Modelling 1

# %%
df = pd.read_csv("final_model_data_V3New.csv")
df
# Out:
#      Unnamed: 0  Unnamed: 0.1     ID  SEASON           CITY CITY_Corrrected  \
# 0             0             0     60    2008      Bangalore             RCB
# 1             1             1     61    2008     Chandigarh            KXIP
# 2             2             2     62    2008          Delhi              DD
# 3             3             3     63    2008         Mumbai              MI
# 4             4             4     64    2008        Kolkata             KKR
# ..          ...           ...    ...     ...            ...             ...
# 742         742           742  11346    2019         Mohali            KXIP
# 743         743           743  11347    2019         Mumbai              MI
# 744         744           744  11412    2019        Chennai             CSK
# 745         745           745  11413    2019  Visakhapatnam   Visakhapatnam
# 746         746           746  11414    2019  Visakhapatnam   Visakhapatnam
#
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'ID', 'SEASON', 'CITY', 'CITY_Corrrected',
#        'TEAM1', 'TEAM1_MODEL', 'TEAM2', 'TEAM2_MODEL', 'TEAM1_STRENGTH',
#        'TEAM1_CUMU_STRENGTH', 'TEAM2_STRENGTH', 'TEAM2_CUMU_STRENGTH',
#        'TOSS_WINNER', 'TOSS_DECISION', 'RESULT', 'WINNER', 'WIN_BY_RUNS',
#        'TOSS_WINNER_MODEL', 'WINNER_MODEL', 'TOSS_DECISION_MODEL',
#        'CITY_MODEL', 'WIN_RATE_TEAM1', 'WIN_RATE_TEAM2'],
#       dtype='object')

# %%
df["TOSS_WINNER"]
# Out:
# 0       RCB
# 1       CSK
# 2        RR
# 3        MI
# 4       SRH
#        ...
# 742    KXIP
# 743      MI
# 744     CSK
# 745      DD
# 746     CSK
# Name: TOSS_WINNER, Length: 747, dtype: object

# %%
df.drop(["Unnamed: 0", "Unnamed: 0.1", "ID"], axis=1, inplace = True)
df
# Out:
#      SEASON           CITY CITY_Corrrected TEAM1  TEAM1_MODEL TEAM2  \
# 0      2008      Bangalore             RCB   KKR            1   RCB
# 1      2008     Chandigarh            KXIP   CSK            1  KXIP
# 2      2008          Delhi              DD    DD            1    RR
# 3      2008         Mumbai              MI   RCB            1    MI
# 4      2008        Kolkata             KKR   KKR            1   SRH
# ..      ...            ...             ...   ...          ...   ...
# 742    2019         Mohali            KXIP   CSK            1  KXIP
# 743    2019         Mumbai              MI   KKR            1    MI
# 744    2019        Chennai             CSK   CSK            1    MI
# 745    2019  Visakhapatnam   Visakhapatnam   SRH            1    DD
# 746    2019  Visakhapatnam   Visakhapatnam    DD            1   CSK
#
#      TEAM2_MODEL  TEAM1_STRENGTH  TEAM1_CUMU_STRENGTH  TEAM2_STRENGTH  ...  \
# ...

# %%
df = df[["TEAM1", "TEAM1_MODEL", "TEAM2", "TEAM2_MODEL", "TOSS_WINNER", "TOSS_WINNER_MODEL", "TEAM1_STRENGTH", "TEAM1_CUMU_STRENGTH", \
        "TEAM2_STRENGTH", "TEAM2_CUMU_STRENGTH", "WIN_RATE_TEAM1", "WIN_RATE_TEAM2", "WINNER", "WINNER_MODEL"]]

# %%
df
# Out:
#     TEAM1  TEAM1_MODEL TEAM2  TEAM2_MODEL TOSS_WINNER  TOSS_WINNER_MODEL  \
# 0     KKR            1   RCB            0         RCB                  0
# 1     CSK            1  KXIP            0         CSK                  1
# 2      DD            1    RR            0          RR                  0
# 3     RCB            1    MI            0          MI                  0
# 4     KKR            1   SRH            0         SRH                  0
# ..    ...          ...   ...          ...         ...                ...
# 742   CSK            1  KXIP            0        KXIP                  0
# 743   KKR            1    MI            0          MI                  0
# 744   CSK            1    MI            0         CSK                  1
# 745   SRH            1    DD            0          DD                  0
# 746    DD            1   CSK            0         CSK                  0
#
#      TEAM1_STRENGTH  TEAM1_CUMU_STRENGTH  TEAM2_STRENGTH  TEAM2_CUMU_STRENGTH  \
# ...

# %%
df.isna().sum()
# Out:
# TEAM1                  0
# TEAM1_MODEL            0
# TEAM2                  0
# TEAM2_MODEL            0
# TOSS_WINNER            0
# TOSS_WINNER_MODEL      0
# TEAM1_STRENGTH         0
# TEAM1_CUMU_STRENGTH    0
# TEAM2_STRENGTH         0
# TEAM2_CUMU_STRENGTH    0
# WIN_RATE_TEAM1         0
# WIN_RATE_TEAM2         0
# WINNER                 0
# WINNER_MODEL           0
# dtype: int64

# %%
df["TEAM2"]
# Out:
# 0       RCB
# 1      KXIP
# 2        RR
# 3        MI
# 4       SRH
#        ...
# 742    KXIP
# 743      MI
# 744      MI
# 745      DD
# 746     CSK
# Name: TEAM2, Length: 747, dtype: object

# %%
df[df["TEAM2"] == "GL"]
# Out:
#     TEAM1  TEAM1_MODEL TEAM2  TEAM2_MODEL TOSS_WINNER  TOSS_WINNER_MODEL  \
# 513  KXIP            1    GL            0          GL                  0
# 516   RPS            1    GL            0         RPS                  1
# 519    MI            1    GL            0          GL                  0
# 529   RCB            1    GL            0         RCB                  1
# 535   RPS            1    GL            0          GL                  0
# 538  KXIP            1    GL            0          GL                  0
# 548   KKR            1    GL            0          GL                  0
# 554   RCB            1    GL            0          GL                  0
# 561   KKR            1    GL            0          GL                  0
# 564    MI            1    GL            0          GL                  0
# 573   KKR            1    GL            0         KKR                  1
# 576   SRH            1    GL            0         SRH                  1
# ...

# %%
df[df["TEAM1"] == "GL"]
# Out:
#     TEAM1  TEAM1_MODEL TEAM2  TEAM2_MODEL TOSS_WINNER  TOSS_WINNER_MODEL  \
# 525    GL            1   SRH            0         SRH                  0
# 533    GL            1    DD            0          DD                  0
# 541    GL            1    DD            0          DD                  0
# 544    GL            1   SRH            0         SRH                  0
# 567    GL            1   RCB            0         RCB                  0
# 569    GL            1   SRH            0         SRH                  0
# 583    GL            1   RPS            0          GL                  1
# 593    GL            1   KKR            0          GL                  1
# 600    GL            1   RCB            0          GL                  1
# 616    GL            1  KXIP            0          GL                  1
#
#      TEAM1_STRENGTH  TEAM1_CUMU_STRENGTH  TEAM2_STRENGTH  TEAM2_CUMU_STRENGTH  \
# 525      315.323661           283.078125      276.529412           222.247899
# ...

# %%
df.drop(df[df["TEAM1"] == "KTK"].index, inplace = True) 
df.drop(df[df["TEAM2"] == "KTK"].index, inplace = True) 
df.drop(df[df["TEAM1"] == "GL"].index, inplace = True) 
df.drop(df[df["TEAM2"] == "GL"].index, inplace = True)
# Out:
# C:\Users\khand\anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df
# Out:
#     TEAM1  TEAM1_MODEL TEAM2  TEAM2_MODEL TOSS_WINNER  TOSS_WINNER_MODEL  \
# 0     KKR            1   RCB            0         RCB                  0
# 1     CSK            1  KXIP            0         CSK                  1
# 2      DD            1    RR            0          RR                  0
# 3     RCB            1    MI            0          MI                  0
# 4     KKR            1   SRH            0         SRH                  0
# ..    ...          ...   ...          ...         ...                ...
# 742   CSK            1  KXIP            0        KXIP                  0
# 743   KKR            1    MI            0          MI                  0
# 744   CSK            1    MI            0         CSK                  1
# 745   SRH            1    DD            0          DD                  0
# 746    DD            1   CSK            0         CSK                  0
#
#      TEAM1_STRENGTH  TEAM1_CUMU_STRENGTH  TEAM2_STRENGTH  TEAM2_CUMU_STRENGTH  \
# ...

# %% [markdown]
# ### Modelling without using AHP

# %%
df.columns
# Out:
# Index(['TEAM1', 'TEAM1_MODEL', 'TEAM2', 'TEAM2_MODEL', 'TOSS_WINNER',
#        'TOSS_WINNER_MODEL', 'TEAM1_STRENGTH', 'TEAM1_CUMU_STRENGTH',
#        'TEAM2_STRENGTH', 'TEAM2_CUMU_STRENGTH', 'WIN_RATE_TEAM1',
#        'WIN_RATE_TEAM2', 'WINNER', 'WINNER_MODEL'],
#       dtype='object')

# %%
X = df[['TEAM1_MODEL', 'TEAM2_MODEL', 
       'TOSS_WINNER_MODEL', 'TEAM1_STRENGTH', 'TEAM1_CUMU_STRENGTH',
       'TEAM2_STRENGTH', 'TEAM2_CUMU_STRENGTH', 'WIN_RATE_TEAM1',
       'WIN_RATE_TEAM2']]
y = df["WINNER_MODEL"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    test_size=0.2,
                                                    random_state=12)

# %%
import lazypredict
from lazypredict.Supervised import LazyClassifier
# Out:
# C:\Users\khand\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:144: FutureWarning: The sklearn.utils.testing module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.utils. Anything that cannot be imported from sklearn.utils is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
models,predictions = clf.fit(X_train, X_test, y_train, y_test)
models
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 30/30 [00:01<00:00, 28.89it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# LogisticRegression                 0.60               0.61     0.61      0.58
# RidgeClassifierCV                  0.59               0.60     0.60      0.58
# LinearSVC                          0.58               0.60     0.60      0.57
# LinearDiscriminantAnalysis         0.58               0.60     0.60      0.57
# RidgeClassifier                    0.58               0.60     0.60      0.57
# BaggingClassifier                  0.59               0.59     0.59      0.59
# CalibratedClassifierCV             0.57               0.59     0.59      0.56
# AdaBoostClassifier                 0.57               0.58     0.58      0.57
# XGBClassifier                      0.57               0.57     0.57      0.57
# ...

# %% [markdown]
# ### Adding AHP column and modelling using that

# %% [markdown]
# RPS 	6.032793\
# DD 	    8.076035\
# SRH 	9.026536\
# KXIP 	9.380131\
# RCB 	9.982425\
# RR 	    12.695051\
# KKR 	12.745465\
# MI 	    15.160852\
# CSK 	16.900712

# %%
df_ahp1 = df
df_ahp1
# Out:
#     TEAM1  TEAM1_MODEL TEAM2  TEAM2_MODEL TOSS_WINNER  TOSS_WINNER_MODEL  \
# 0     KKR            1   RCB            0         RCB                  0
# 1     CSK            1  KXIP            0         CSK                  1
# 2      DD            1    RR            0          RR                  0
# 3     RCB            1    MI            0          MI                  0
# 4     KKR            1   SRH            0         SRH                  0
# ..    ...          ...   ...          ...         ...                ...
# 742   CSK            1  KXIP            0        KXIP                  0
# 743   KKR            1    MI            0          MI                  0
# 744   CSK            1    MI            0         CSK                  1
# 745   SRH            1    DD            0          DD                  0
# 746    DD            1   CSK            0         CSK                  0
#
#      TEAM1_STRENGTH  TEAM1_CUMU_STRENGTH  TEAM2_STRENGTH  TEAM2_CUMU_STRENGTH  \
# ...

# %%
df_ahp1["AHP_RATIO_TEAM1"] = ''
df_ahp1["AHP_RATIO_TEAM2"] = ''


for i in range(0, 703):
    if df_ahp1["TEAM1"].iloc[i] == "CSK":
        df_ahp1["AHP_RATIO_TEAM1"].iloc[i] = 16.900712
    
    elif df_ahp1["TEAM1"].iloc[i] == "MI":
        df_ahp1["AHP_RATIO_TEAM1"].iloc[i] = 15.160852
    
    elif df_ahp1["TEAM1"].iloc[i] == "KKR":
        df_ahp1["AHP_RATIO_TEAM1"].iloc[i] = 12.745465
    
    elif df_ahp1["TEAM1"].iloc[i] == "RR":
        df_ahp1["AHP_RATIO_TEAM1"].iloc[i] = 12.695051
    
    elif df_ahp1["TEAM1"].iloc[i] == "RCB":
        df_ahp1["AHP_RATIO_TEAM1"].iloc[i] = 9.982425
    
    elif df_ahp1["TEAM1"].iloc[i] == "KXIP":
        df_ahp1["AHP_RATIO_TEAM1"].iloc[i] = 9.380131
    
    elif df_ahp1["TEAM1"].iloc[i] == "SRH":
        df_ahp1["AHP_RATIO_TEAM1"].iloc[i] = 9.026536
        
    elif df_ahp1["TEAM1"].iloc[i] == "DD":
        df_ahp1["AHP_RATIO_TEAM1"].iloc[i] = 8.076035
    
    elif df_ahp1["TEAM1"].iloc[i] == "RPS":
        df_ahp1["AHP_RATIO_TEAM1"].iloc[i] = 6.032793
    
        
for i in range(0, 703):       
    if df_ahp1["TEAM2"].iloc[i] == "CSK":
        df_ahp1["AHP_RATIO_TEAM2"].iloc[i] = 16.900712
        
    elif df_ahp1["TEAM2"].iloc[i] == "MI":
        df_ahp1["AHP_RATIO_TEAM2"].iloc[i] = 15.160852
        
    elif df_ahp1["TEAM2"].iloc[i] == "KKR":
        df_ahp1["AHP_RATIO_TEAM2"].iloc[i] = 12.745465
        
    elif df_ahp1["TEAM2"].iloc[i] == "RR":
        df_ahp1["AHP_RATIO_TEAM2"].iloc[i] = 12.695051
        
    elif df_ahp1["TEAM2"].iloc[i] == "RCB":
        df_ahp1["AHP_RATIO_TEAM2"].iloc[i] = 9.982425
        
    elif df_ahp1["TEAM2"].iloc[i] == "KXIP":
        df_ahp1["AHP_RATIO_TEAM2"].iloc[i] = 9.380131
        
    elif df_ahp1["TEAM2"].iloc[i] == "SRH":
        df_ahp1["AHP_RATIO_TEAM2"].iloc[i] = 9.026536
        
    elif df_ahp1["TEAM2"].iloc[i] == "DD":
        df_ahp1["AHP_RATIO_TEAM2"].iloc[i] = 8.076035
        
    elif df_ahp1["TEAM2"].iloc[i] == "RPS":
        df_ahp1["AHP_RATIO_TEAM2"].iloc[i] = 6.032793

# %%
df_ahp1
# Out:
#     TEAM1  TEAM1_MODEL TEAM2  TEAM2_MODEL TOSS_WINNER  TOSS_WINNER_MODEL  \
# 0     KKR            1   RCB            0         RCB                  0
# 1     CSK            1  KXIP            0         CSK                  1
# 2      DD            1    RR            0          RR                  0
# 3     RCB            1    MI            0          MI                  0
# 4     KKR            1   SRH            0         SRH                  0
# ..    ...          ...   ...          ...         ...                ...
# 742   CSK            1  KXIP            0        KXIP                  0
# 743   KKR            1    MI            0          MI                  0
# 744   CSK            1    MI            0         CSK                  1
# 745   SRH            1    DD            0          DD                  0
# 746    DD            1   CSK            0         CSK                  0
#
#      TEAM1_STRENGTH  TEAM1_CUMU_STRENGTH  TEAM2_STRENGTH  TEAM2_CUMU_STRENGTH  \
# ...

# %%
df_ahp1.isna().sum()
# Out:
# TEAM1                  0
# TEAM1_MODEL            0
# TEAM2                  0
# TEAM2_MODEL            0
# TOSS_WINNER            0
# TOSS_WINNER_MODEL      0
# TEAM1_STRENGTH         0
# TEAM1_CUMU_STRENGTH    0
# TEAM2_STRENGTH         0
# TEAM2_CUMU_STRENGTH    0
# WIN_RATE_TEAM1         0
# WIN_RATE_TEAM2         0
# WINNER                 0
# WINNER_MODEL           0
# AHP_RATIO_TEAM1        0
# AHP_RATIO_TEAM2        0
# dtype: int64

# %%
# df_ahp1.to_csv("no_innings_ahp_column.csv", index=False)

# %%
X = df_ahp1[['TEAM1_MODEL', 'TEAM2_MODEL', 
       'TOSS_WINNER_MODEL', 'TEAM1_STRENGTH', 'TEAM1_CUMU_STRENGTH',
       'TEAM2_STRENGTH', 'TEAM2_CUMU_STRENGTH', 'WIN_RATE_TEAM1',
       'WIN_RATE_TEAM2', 'AHP_RATIO_TEAM1', 'AHP_RATIO_TEAM2']]
y = df_ahp1["WINNER_MODEL"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    test_size=0.2,
                                                    random_state=12)

# %%
clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
models,predictions = clf.fit(X_train, X_test, y_train, y_test)
models
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 30/30 [00:01<00:00, 21.21it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# ExtraTreesClassifier               0.58               0.59     0.59      0.58
# RidgeClassifierCV                  0.57               0.58     0.58      0.57
# LogisticRegression                 0.57               0.58     0.58      0.57
# AdaBoostClassifier                 0.57               0.58     0.58      0.56
# SVC                                0.57               0.58     0.58      0.56
# CalibratedClassifierCV             0.57               0.58     0.58      0.56
# RidgeClassifier                    0.57               0.57     0.57      0.57
# LinearDiscriminantAnalysis         0.57               0.57     0.57      0.57
# LinearSVC                          0.57               0.57     0.57      0.57
# ...

# %% [markdown]
# ## Dataset 1- Modelling 2

# %%
df_ahp1
# Out:
#     TEAM1  TEAM1_MODEL TEAM2  TEAM2_MODEL TOSS_WINNER  TOSS_WINNER_MODEL  \
# 0     KKR            1   RCB            0         RCB                  0
# 1     CSK            1  KXIP            0         CSK                  1
# 2      DD            1    RR            0          RR                  0
# 3     RCB            1    MI            0          MI                  0
# 4     KKR            1   SRH            0         SRH                  0
# ..    ...          ...   ...          ...         ...                ...
# 742   CSK            1  KXIP            0        KXIP                  0
# 743   KKR            1    MI            0          MI                  0
# 744   CSK            1    MI            0         CSK                  1
# 745   SRH            1    DD            0          DD                  0
# 746    DD            1   CSK            0         CSK                  0
#
#      TEAM1_STRENGTH  TEAM1_CUMU_STRENGTH  TEAM2_STRENGTH  TEAM2_CUMU_STRENGTH  \
# ...

# %%
## Divided by the mean.

# %% [markdown]
# RPS 	0.542951\
# DD 	    0.726843\
# SRH 	0.812388\
# KXIP 	0.844212\
# RCB 	0.898418\
# RR 	    1.142555\
# KKR 	1.147092\
# MI 	    1.364477\
# CSK 	1.521064

# %%
for i in range(0, 703):
    if df_ahp1["TEAM1"].iloc[i] == "CSK":
        df_ahp1["TEAM1_STRENGTH"].iloc[i] = df_ahp1["TEAM1_STRENGTH"].iloc[i] * 1.521064
        df_ahp1["TEAM1_CUMU_STRENGTH"].iloc[i] = df_ahp1["TEAM1_CUMU_STRENGTH"].iloc[i] * 1.521064
        df_ahp1["WIN_RATE_TEAM1"].iloc[i] = df_ahp1["WIN_RATE_TEAM1"].iloc[i] * 1.521064
    
    elif df_ahp1["TEAM1"].iloc[i] == "MI":
        df_ahp1["TEAM1_STRENGTH"].iloc[i] = df_ahp1["TEAM1_STRENGTH"].iloc[i] * 1.364477
        df_ahp1["TEAM1_CUMU_STRENGTH"].iloc[i] = df_ahp1["TEAM1_CUMU_STRENGTH"].iloc[i] * 1.364477
        df_ahp1["WIN_RATE_TEAM1"].iloc[i] = df_ahp1["WIN_RATE_TEAM1"].iloc[i] * 1.364477
    
    elif df_ahp1["TEAM1"].iloc[i] == "KKR":
        df_ahp1["TEAM1_STRENGTH"].iloc[i] = df_ahp1["TEAM1_STRENGTH"].iloc[i] * 1.147092
        df_ahp1["TEAM1_CUMU_STRENGTH"].iloc[i] = df_ahp1["TEAM1_CUMU_STRENGTH"].iloc[i] * 1.147092
        df_ahp1["WIN_RATE_TEAM1"].iloc[i] = df_ahp1["WIN_RATE_TEAM1"].iloc[i] * 1.147092
    
    elif df_ahp1["TEAM1"].iloc[i] == "RR":
        df_ahp1["TEAM1_STRENGTH"].iloc[i] = df_ahp1["TEAM1_STRENGTH"].iloc[i] * 1.142555
        df_ahp1["TEAM1_CUMU_STRENGTH"].iloc[i] = df_ahp1["TEAM1_CUMU_STRENGTH"].iloc[i] * 1.142555
        df_ahp1["WIN_RATE_TEAM1"].iloc[i] = df_ahp1["WIN_RATE_TEAM1"].iloc[i] * 1.142555
    
    elif df_ahp1["TEAM1"].iloc[i] == "RCB":
        df_ahp1["TEAM1_STRENGTH"].iloc[i] = df_ahp1["TEAM1_STRENGTH"].iloc[i] * 0.898418
        df_ahp1["TEAM1_CUMU_STRENGTH"].iloc[i] = df_ahp1["TEAM1_CUMU_STRENGTH"].iloc[i] * 0.898418
        df_ahp1["WIN_RATE_TEAM1"].iloc[i] = df_ahp1["WIN_RATE_TEAM1"].iloc[i] * 0.898418
    
    elif df_ahp1["TEAM1"].iloc[i] == "KXIP":
        df_ahp1["TEAM1_STRENGTH"].iloc[i] = df_ahp1["TEAM1_STRENGTH"].iloc[i] * 0.844212
        df_ahp1["TEAM1_CUMU_STRENGTH"].iloc[i] = df_ahp1["TEAM1_CUMU_STRENGTH"].iloc[i] * 0.844212
        df_ahp1["WIN_RATE_TEAM1"].iloc[i] = df_ahp1["WIN_RATE_TEAM1"].iloc[i] * 0.844212
    
    elif df_ahp1["TEAM1"].iloc[i] == "SRH":
        df_ahp1["TEAM1_STRENGTH"].iloc[i] = df_ahp1["TEAM1_STRENGTH"].iloc[i] * 0.812388
        df_ahp1["TEAM1_CUMU_STRENGTH"].iloc[i] = df_ahp1["TEAM1_CUMU_STRENGTH"].iloc[i] * 0.812388
        df_ahp1["WIN_RATE_TEAM1"].iloc[i] = df_ahp1["WIN_RATE_TEAM1"].iloc[i] * 0.812388

    elif df_ahp1["TEAM1"].iloc[i] == "DD":
        df_ahp1["TEAM1_STRENGTH"].iloc[i] = df_ahp1["TEAM1_STRENGTH"].iloc[i] * 0.726843
        df_ahp1["TEAM1_CUMU_STRENGTH"].iloc[i] = df_ahp1["TEAM1_CUMU_STRENGTH"].iloc[i] * 0.726843
        df_ahp1["WIN_RATE_TEAM1"].iloc[i] = df_ahp1["WIN_RATE_TEAM1"].iloc[i] * 0.726843
    
    elif df_ahp1["TEAM1"].iloc[i] == "RPS":
        df_ahp1["TEAM1_STRENGTH"].iloc[i] = df_ahp1["TEAM1_STRENGTH"].iloc[i] * 0.542951
        df_ahp1["TEAM1_CUMU_STRENGTH"].iloc[i] = df_ahp1["TEAM1_CUMU_STRENGTH"].iloc[i] * 0.542951
        df_ahp1["WIN_RATE_TEAM1"].iloc[i] = df_ahp1["WIN_RATE_TEAM1"].iloc[i] * 0.542951
        

for i in range(0, 703):
    if df_ahp1["TEAM2"].iloc[i] == "CSK":
        df_ahp1["TEAM2_STRENGTH"].iloc[i] = df_ahp1["TEAM2_STRENGTH"].iloc[i] * 1.521064
        df_ahp1["TEAM2_CUMU_STRENGTH"].iloc[i] = df_ahp1["TEAM2_CUMU_STRENGTH"].iloc[i] * 1.521064
        df_ahp1["WIN_RATE_TEAM2"].iloc[i] = df_ahp1["WIN_RATE_TEAM2"].iloc[i] * 1.521064
    
    elif df_ahp1["TEAM2"].iloc[i] == "MI":
        df_ahp1["TEAM2_STRENGTH"].iloc[i] = df_ahp1["TEAM2_STRENGTH"].iloc[i] * 1.364477
        df_ahp1["TEAM2_CUMU_STRENGTH"].iloc[i] = df_ahp1["TEAM2_CUMU_STRENGTH"].iloc[i] * 1.364477
        df_ahp1["WIN_RATE_TEAM2"].iloc[i] = df_ahp1["WIN_RATE_TEAM2"].iloc[i] * 1.364477
    
    elif df_ahp1["TEAM2"].iloc[i] == "KKR":
        df_ahp1["TEAM2_STRENGTH"].iloc[i] = df_ahp1["TEAM2_STRENGTH"].iloc[i] * 1.147092
        df_ahp1["TEAM2_CUMU_STRENGTH"].iloc[i] = df_ahp1["TEAM2_CUMU_STRENGTH"].iloc[i] * 1.147092
        df_ahp1["WIN_RATE_TEAM2"].iloc[i] = df_ahp1["WIN_RATE_TEAM2"].iloc[i] * 1.147092
    
    elif df_ahp1["TEAM2"].iloc[i] == "RR":
        df_ahp1["TEAM2_STRENGTH"].iloc[i] = df_ahp1["TEAM2_STRENGTH"].iloc[i] * 1.142555
        df_ahp1["TEAM2_CUMU_STRENGTH"].iloc[i] = df_ahp1["TEAM2_CUMU_STRENGTH"].iloc[i] * 1.142555
        df_ahp1["WIN_RATE_TEAM2"].iloc[i] = df_ahp1["WIN_RATE_TEAM2"].iloc[i] * 1.142555
    
    elif df_ahp1["TEAM2"].iloc[i] == "RCB":
        df_ahp1["TEAM2_STRENGTH"].iloc[i] = df_ahp1["TEAM2_STRENGTH"].iloc[i] * 0.898418
        df_ahp1["TEAM2_CUMU_STRENGTH"].iloc[i] = df_ahp1["TEAM2_CUMU_STRENGTH"].iloc[i] * 0.898418
        df_ahp1["WIN_RATE_TEAM2"].iloc[i] = df_ahp1["WIN_RATE_TEAM2"].iloc[i] * 0.898418
    
    elif df_ahp1["TEAM2"].iloc[i] == "KXIP":
        df_ahp1["TEAM2_STRENGTH"].iloc[i] = df_ahp1["TEAM2_STRENGTH"].iloc[i] * 0.844212
        df_ahp1["TEAM2_CUMU_STRENGTH"].iloc[i] = df_ahp1["TEAM2_CUMU_STRENGTH"].iloc[i] * 0.844212
        df_ahp1["WIN_RATE_TEAM2"].iloc[i] = df_ahp1["WIN_RATE_TEAM2"].iloc[i] * 0.844212
    
    elif df_ahp1["TEAM1"].iloc[i] == "SRH":
        df_ahp1["TEAM2_STRENGTH"].iloc[i] = df_ahp1["TEAM2_STRENGTH"].iloc[i] * 0.812388
        df_ahp1["TEAM2_CUMU_STRENGTH"].iloc[i] = df_ahp1["TEAM2_CUMU_STRENGTH"].iloc[i] * 0.812388
        df_ahp1["WIN_RATE_TEAM2"].iloc[i] = df_ahp1["WIN_RATE_TEAM2"].iloc[i] * 0.812388

    elif df_ahp1["TEAM1"].iloc[i] == "DD":
        df_ahp1["TEAM2_STRENGTH"].iloc[i] = df_ahp1["TEAM2_STRENGTH"].iloc[i] * 0.726843
        df_ahp1["TEAM2_CUMU_STRENGTH"].iloc[i] = df_ahp1["TEAM2_CUMU_STRENGTH"].iloc[i] * 0.726843
        df_ahp1["WIN_RATE_TEAM2"].iloc[i] = df_ahp1["WIN_RATE_TEAM2"].iloc[i] * 0.726843
    
    elif df_ahp1["TEAM2"].iloc[i] == "RPS":
        df_ahp1["TEAM2_STRENGTH"].iloc[i] = df_ahp1["TEAM2_STRENGTH"].iloc[i] * 0.542951
        df_ahp1["TEAM2_CUMU_STRENGTH"].iloc[i] = df_ahp1["TEAM2_CUMU_STRENGTH"].iloc[i] * 0.542951
        df_ahp1["WIN_RATE_TEAM2"].iloc[i] = df_ahp1["WIN_RATE_TEAM2"].iloc[i] * 0.542951

# %%
df_ahp1
# Out:
#     TEAM1  TEAM1_MODEL TEAM2  TEAM2_MODEL TOSS_WINNER  TOSS_WINNER_MODEL  \
# 0     KKR            1   RCB            0         RCB                  0
# 1     CSK            1  KXIP            0         CSK                  1
# 2      DD            1    RR            0          RR                  0
# 3     RCB            1    MI            0          MI                  0
# 4     KKR            1   SRH            0         SRH                  0
# ..    ...          ...   ...          ...         ...                ...
# 742   CSK            1  KXIP            0        KXIP                  0
# 743   KKR            1    MI            0          MI                  0
# 744   CSK            1    MI            0         CSK                  1
# 745   SRH            1    DD            0          DD                  0
# 746    DD            1   CSK            0         CSK                  0
#
#      TEAM1_STRENGTH  TEAM1_CUMU_STRENGTH  TEAM2_STRENGTH  TEAM2_CUMU_STRENGTH  \
# ...

# %%
# df_ahp1.to_csv("no_innings_ahp_mean.csv", index=False)

# %%
X = df[['TEAM1_MODEL', 'TEAM2_MODEL', 
       'TOSS_WINNER_MODEL', 'TEAM1_STRENGTH', 'TEAM1_CUMU_STRENGTH',
       'TEAM2_STRENGTH', 'TEAM2_CUMU_STRENGTH', 'WIN_RATE_TEAM1',
       'WIN_RATE_TEAM2']]
y = df["WINNER_MODEL"]

X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    test_size=0.2,
                                                    random_state=12)

clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
models,predictions = clf.fit(X_train, X_test, y_train, y_test)
models
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 30/30 [00:01<00:00, 26.91it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# CalibratedClassifierCV             0.64               0.64     0.64      0.64
# SVC                                0.63               0.64     0.64      0.63
# LGBMClassifier                     0.63               0.63     0.63      0.63
# RandomForestClassifier             0.62               0.63     0.63      0.62
# LinearDiscriminantAnalysis         0.61               0.62     0.62      0.61
# RidgeClassifier                    0.61               0.62     0.62      0.61
# LogisticRegression                 0.61               0.62     0.62      0.61
# LinearSVC                          0.61               0.62     0.62      0.61
# RidgeClassifierCV                  0.61               0.61     0.61      0.61
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
model.score(X_train, y_train)
# Out:
# 1.0

# %%
model.score(X_test, y_test)
# Out:
# 0.624113475177305

# %% [markdown]
# # Dataset 2 with Innings Multiplied

# %% [markdown]
# ## Dataset 2 - Modelling 1

# %%
df = pd.read_csv("strength_by_innings_new.csv")
df
# Out:
#      Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1     ID  SEASON           CITY  \
# 0             0             0               0     60    2008      Bangalore
# 1             1             1               1     61    2008     Chandigarh
# 2             2             2               2     62    2008          Delhi
# 3             3             3               3     63    2008         Mumbai
# 4             4             4               4     64    2008        Kolkata
# ..          ...           ...             ...    ...     ...            ...
# 742         742           742             742  11346    2019         Mohali
# 743         743           743             743  11347    2019         Mumbai
# 744         744           744             744  11412    2019        Chennai
# 745         745           745             745  11413    2019  Visakhapatnam
# 746         746           746             746  11414    2019  Visakhapatnam
#
# ...

# %%
df = df[["TEAM1", "TEAM1_MODEL", "TEAM2", "TEAM2_MODEL", "TOSS_WINNER", "TOSS_WINNER_MODEL", "TEAM1_STRENGTH", "TEAM1_CUMU_STRENGTH", \
        "TEAM2_STRENGTH", "TEAM2_CUMU_STRENGTH", "WIN_RATE_TEAM1", "WIN_RATE_TEAM2", "WINNER", "WINNER_MODEL"]]

# %%
df
# Out:
#     TEAM1  TEAM1_MODEL TEAM2  TEAM2_MODEL TOSS_WINNER  TOSS_WINNER_MODEL  \
# 0     KKR            1   RCB            0         RCB                  0
# 1     CSK            1  KXIP            0         CSK                  1
# 2      DD            1    RR            0          RR                  0
# 3     RCB            1    MI            0          MI                  0
# 4     KKR            1   SRH            0         SRH                  0
# ..    ...          ...   ...          ...         ...                ...
# 742   CSK            1  KXIP            0        KXIP                  0
# 743   KKR            1    MI            0          MI                  0
# 744   CSK            1    MI            0         CSK                  1
# 745   SRH            1    DD            0          DD                  0
# 746    DD            1   CSK            0         CSK                  0
#
#      TEAM1_STRENGTH  TEAM1_CUMU_STRENGTH  TEAM2_STRENGTH  TEAM2_CUMU_STRENGTH  \
# ...

# %%
df.drop(df[df["TEAM1"] == "KTK"].index, inplace = True) 
df.drop(df[df["TEAM2"] == "KTK"].index, inplace = True) 
df.drop(df[df["TEAM1"] == "GL"].index, inplace = True) 
df.drop(df[df["TEAM2"] == "GL"].index, inplace = True)

# %%
df
# Out:
#     TEAM1  TEAM1_MODEL TEAM2  TEAM2_MODEL TOSS_WINNER  TOSS_WINNER_MODEL  \
# 0     KKR            1   RCB            0         RCB                  0
# 1     CSK            1  KXIP            0         CSK                  1
# 2      DD            1    RR            0          RR                  0
# 3     RCB            1    MI            0          MI                  0
# 4     KKR            1   SRH            0         SRH                  0
# ..    ...          ...   ...          ...         ...                ...
# 742   CSK            1  KXIP            0        KXIP                  0
# 743   KKR            1    MI            0          MI                  0
# 744   CSK            1    MI            0         CSK                  1
# 745   SRH            1    DD            0          DD                  0
# 746    DD            1   CSK            0         CSK                  0
#
#      TEAM1_STRENGTH  TEAM1_CUMU_STRENGTH  TEAM2_STRENGTH  TEAM2_CUMU_STRENGTH  \
# ...

# %% [markdown]
# ### Modelling without using AHP

# %%
X = df[['TEAM1_MODEL', 'TEAM2_MODEL', 
       'TOSS_WINNER_MODEL', 'TEAM1_STRENGTH', 'TEAM1_CUMU_STRENGTH',
       'TEAM2_STRENGTH', 'TEAM2_CUMU_STRENGTH', 'WIN_RATE_TEAM1',
       'WIN_RATE_TEAM2']]
y = df["WINNER_MODEL"]

X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    test_size=0.2,
                                                    random_state=12)

clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
models,predictions = clf.fit(X_train, X_test, y_train, y_test)
models
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 30/30 [00:01<00:00, 26.11it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# LinearSVC                          0.57               0.58     0.58      0.57
# RidgeClassifier                    0.57               0.58     0.58      0.57
# CalibratedClassifierCV             0.57               0.58     0.58      0.57
# RidgeClassifierCV                  0.57               0.58     0.58      0.57
# LinearDiscriminantAnalysis         0.57               0.58     0.58      0.57
# LogisticRegression                 0.57               0.57     0.57      0.57
# SGDClassifier                      0.57               0.57     0.57      0.57
# DecisionTreeClassifier             0.57               0.57     0.57      0.57
# SVC                                0.55               0.56     0.56      0.55
# ...

# %%
df_ahp2 = df
df_ahp2
# Out:
#     TEAM1  TEAM1_MODEL TEAM2  TEAM2_MODEL TOSS_WINNER  TOSS_WINNER_MODEL  \
# 0     KKR            1   RCB            0         RCB                  0
# 1     CSK            1  KXIP            0         CSK                  1
# 2      DD            1    RR            0          RR                  0
# 3     RCB            1    MI            0          MI                  0
# 4     KKR            1   SRH            0         SRH                  0
# ..    ...          ...   ...          ...         ...                ...
# 742   CSK            1  KXIP            0        KXIP                  0
# 743   KKR            1    MI            0          MI                  0
# 744   CSK            1    MI            0         CSK                  1
# 745   SRH            1    DD            0          DD                  0
# 746    DD            1   CSK            0         CSK                  0
#
#      TEAM1_STRENGTH  TEAM1_CUMU_STRENGTH  TEAM2_STRENGTH  TEAM2_CUMU_STRENGTH  \
# ...

# %%
df_ahp2["AHP_RATIO_TEAM1"] = ''
df_ahp2["AHP_RATIO_TEAM2"] = ''


for i in range(0, 703):
    if df_ahp2["TEAM1"].iloc[i] == "CSK":
        df_ahp2["AHP_RATIO_TEAM1"].iloc[i] = 16.900712
    
    elif df_ahp2["TEAM1"].iloc[i] == "MI":
        df_ahp2["AHP_RATIO_TEAM1"].iloc[i] = 15.160852
    
    elif df_ahp2["TEAM1"].iloc[i] == "KKR":
        df_ahp2["AHP_RATIO_TEAM1"].iloc[i] = 12.745465
    
    elif df_ahp2["TEAM1"].iloc[i] == "RR":
        df_ahp2["AHP_RATIO_TEAM1"].iloc[i] = 12.695051
    
    elif df_ahp2["TEAM1"].iloc[i] == "RCB":
        df_ahp2["AHP_RATIO_TEAM1"].iloc[i] = 9.982425
    
    elif df_ahp2["TEAM1"].iloc[i] == "KXIP":
        df_ahp2["AHP_RATIO_TEAM1"].iloc[i] = 9.380131
    
    elif df_ahp2["TEAM1"].iloc[i] == "SRH":
        df_ahp2["AHP_RATIO_TEAM1"].iloc[i] = 9.026536
        
    elif df_ahp2["TEAM1"].iloc[i] == "DD":
        df_ahp1["AHP_RATIO_TEAM1"].iloc[i] = 8.076035
    
    elif df_ahp2["TEAM1"].iloc[i] == "RPS":
        df_ahp1["AHP_RATIO_TEAM1"].iloc[i] = 6.032793
    
        
for i in range(0, 703):       
    if df_ahp2["TEAM2"].iloc[i] == "CSK":
        df_ahp2["AHP_RATIO_TEAM2"].iloc[i] = 16.900712
        
    elif df_ahp2["TEAM2"].iloc[i] == "MI":
        df_ahp2["AHP_RATIO_TEAM2"].iloc[i] = 15.160852
        
    elif df_ahp2["TEAM2"].iloc[i] == "KKR":
        df_ahp2["AHP_RATIO_TEAM2"].iloc[i] = 12.745465
        
    elif df_ahp2["TEAM2"].iloc[i] == "RR":
        df_ahp2["AHP_RATIO_TEAM2"].iloc[i] = 12.695051
        
    elif df_ahp2["TEAM2"].iloc[i] == "RCB":
        df_ahp2["AHP_RATIO_TEAM2"].iloc[i] = 9.982425
        
    elif df_ahp2["TEAM2"].iloc[i] == "KXIP":
        df_ahp2["AHP_RATIO_TEAM2"].iloc[i] = 9.380131
        
    elif df_ahp2["TEAM2"].iloc[i] == "SRH":
        df_ahp2["AHP_RATIO_TEAM2"].iloc[i] = 9.026536
        
    elif df_ahp2["TEAM2"].iloc[i] == "DD":
        df_ahp2["AHP_RATIO_TEAM2"].iloc[i] = 8.076035
        
    elif df_ahp2["TEAM2"].iloc[i] == "RPS":
        df_ahp2["AHP_RATIO_TEAM2"].iloc[i] = 6.032793

# %%
df_ahp2
# Out:
#     TEAM1  TEAM1_MODEL TEAM2  TEAM2_MODEL TOSS_WINNER  TOSS_WINNER_MODEL  \
# 0     KKR            1   RCB            0         RCB                  0
# 1     CSK            1  KXIP            0         CSK                  1
# 2      DD            1    RR            0          RR                  0
# 3     RCB            1    MI            0          MI                  0
# 4     KKR            1   SRH            0         SRH                  0
# ..    ...          ...   ...          ...         ...                ...
# 742   CSK            1  KXIP            0        KXIP                  0
# 743   KKR            1    MI            0          MI                  0
# 744   CSK            1    MI            0         CSK                  1
# 745   SRH            1    DD            0          DD                  0
# 746    DD            1   CSK            0         CSK                  0
#
#      TEAM1_STRENGTH  TEAM1_CUMU_STRENGTH  TEAM2_STRENGTH  TEAM2_CUMU_STRENGTH  \
# ...

# %%
# df_ahp1.to_csv("innings_ahp_column.csv", index=False)

# %%
X = df_ahp1[['TEAM1_MODEL', 'TEAM2_MODEL', 
       'TOSS_WINNER_MODEL', 'TEAM1_STRENGTH', 'TEAM1_CUMU_STRENGTH',
       'TEAM2_STRENGTH', 'TEAM2_CUMU_STRENGTH', 'WIN_RATE_TEAM1',
       'WIN_RATE_TEAM2', 'AHP_RATIO_TEAM1', 'AHP_RATIO_TEAM2']]
y = df_ahp1["WINNER_MODEL"]

X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    test_size=0.2,
                                                    random_state=12)

clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
models,predictions = clf.fit(X_train, X_test, y_train, y_test)
models
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 30/30 [00:01<00:00, 22.81it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# SGDClassifier                      0.63               0.62     0.62      0.63
# LGBMClassifier                     0.62               0.62     0.62      0.62
# BaggingClassifier                  0.60               0.61     0.61      0.60
# XGBClassifier                      0.59               0.59     0.59      0.59
# SVC                                0.58               0.59     0.59      0.58
# LogisticRegression                 0.57               0.58     0.58      0.56
# RidgeClassifier                    0.57               0.58     0.58      0.56
# BernoulliNB                        0.57               0.58     0.58      0.58
# ExtraTreesClassifier               0.57               0.57     0.57      0.57
# ...

# %% [markdown]
# ## Dataset 2- Modelling 2

# %%
df_ahp2
# Out:
#     TEAM1  TEAM1_MODEL TEAM2  TEAM2_MODEL TOSS_WINNER  TOSS_WINNER_MODEL  \
# 0     KKR            1   RCB            0         RCB                  0
# 1     CSK            1  KXIP            0         CSK                  1
# 2      DD            1    RR            0          RR                  0
# 3     RCB            1    MI            0          MI                  0
# 4     KKR            1   SRH            0         SRH                  0
# ..    ...          ...   ...          ...         ...                ...
# 742   CSK            1  KXIP            0        KXIP                  0
# 743   KKR            1    MI            0          MI                  0
# 744   CSK            1    MI            0         CSK                  1
# 745   SRH            1    DD            0          DD                  0
# 746    DD            1   CSK            0         CSK                  0
#
#      TEAM1_STRENGTH  TEAM1_CUMU_STRENGTH  TEAM2_STRENGTH  TEAM2_CUMU_STRENGTH  \
# ...

# %%
for i in range(0, 703):
    if df_ahp2["TEAM1"].iloc[i] == "CSK":
        df_ahp2["TEAM1_STRENGTH"].iloc[i] = df_ahp2["TEAM1_STRENGTH"].iloc[i] * 1.521064
        df_ahp2["TEAM1_CUMU_STRENGTH"].iloc[i] = df_ahp2["TEAM1_CUMU_STRENGTH"].iloc[i] * 1.521064
        df_ahp2["WIN_RATE_TEAM1"].iloc[i] = df_ahp2["WIN_RATE_TEAM1"].iloc[i] * 1.521064
    
    elif df_ahp2["TEAM1"].iloc[i] == "MI":
        df_ahp2["TEAM1_STRENGTH"].iloc[i] = df_ahp2["TEAM1_STRENGTH"].iloc[i] * 1.364477
        df_ahp2["TEAM1_CUMU_STRENGTH"].iloc[i] = df_ahp2["TEAM1_CUMU_STRENGTH"].iloc[i] * 1.364477
        df_ahp2["WIN_RATE_TEAM1"].iloc[i] = df_ahp2["WIN_RATE_TEAM1"].iloc[i] * 1.364477
    
    elif df_ahp2["TEAM1"].iloc[i] == "KKR":
        df_ahp2["TEAM1_STRENGTH"].iloc[i] = df_ahp2["TEAM1_STRENGTH"].iloc[i] * 1.147092
        df_ahp2["TEAM1_CUMU_STRENGTH"].iloc[i] = df_ahp2["TEAM1_CUMU_STRENGTH"].iloc[i] * 1.147092
        df_ahp2["WIN_RATE_TEAM1"].iloc[i] = df_ahp2["WIN_RATE_TEAM1"].iloc[i] * 1.147092
    
    elif df_ahp2["TEAM1"].iloc[i] == "RR":
        df_ahp2["TEAM1_STRENGTH"].iloc[i] = df_ahp2["TEAM1_STRENGTH"].iloc[i] * 1.142555
        df_ahp2["TEAM1_CUMU_STRENGTH"].iloc[i] = df_ahp2["TEAM1_CUMU_STRENGTH"].iloc[i] * 1.142555
        df_ahp2["WIN_RATE_TEAM1"].iloc[i] = df_ahp2["WIN_RATE_TEAM1"].iloc[i] * 1.142555
    
    elif df_ahp2["TEAM1"].iloc[i] == "RCB":
        df_ahp2["TEAM1_STRENGTH"].iloc[i] = df_ahp2["TEAM1_STRENGTH"].iloc[i] * 0.898418
        df_ahp2["TEAM1_CUMU_STRENGTH"].iloc[i] = df_ahp2["TEAM1_CUMU_STRENGTH"].iloc[i] * 0.898418
        df_ahp2["WIN_RATE_TEAM1"].iloc[i] = df_ahp2["WIN_RATE_TEAM1"].iloc[i] * 0.898418
    
    elif df_ahp2["TEAM1"].iloc[i] == "KXIP":
        df_ahp2["TEAM1_STRENGTH"].iloc[i] = df_ahp2["TEAM1_STRENGTH"].iloc[i] * 0.844212
        df_ahp2["TEAM1_CUMU_STRENGTH"].iloc[i] = df_ahp2["TEAM1_CUMU_STRENGTH"].iloc[i] * 0.844212
        df_ahp2["WIN_RATE_TEAM1"].iloc[i] = df_ahp2["WIN_RATE_TEAM1"].iloc[i] * 0.844212
    
    elif df_ahp2["TEAM1"].iloc[i] == "SRH":
        df_ahp2["TEAM1_STRENGTH"].iloc[i] = df_ahp2["TEAM1_STRENGTH"].iloc[i] * 0.812388
        df_ahp2["TEAM1_CUMU_STRENGTH"].iloc[i] = df_ahp2["TEAM1_CUMU_STRENGTH"].iloc[i] * 0.812388
        df_ahp2["WIN_RATE_TEAM1"].iloc[i] = df_ahp2["WIN_RATE_TEAM1"].iloc[i] * 0.812388

    elif df_ahp2["TEAM1"].iloc[i] == "DD":
        df_ahp2["TEAM1_STRENGTH"].iloc[i] = df_ahp2["TEAM1_STRENGTH"].iloc[i] * 0.726843
        df_ahp2["TEAM1_CUMU_STRENGTH"].iloc[i] = df_ahp2["TEAM1_CUMU_STRENGTH"].iloc[i] * 0.726843
        df_ahp2["WIN_RATE_TEAM1"].iloc[i] = df_ahp2["WIN_RATE_TEAM1"].iloc[i] * 0.726843
    
    elif df_ahp2["TEAM1"].iloc[i] == "RPS":
        df_ahp2["TEAM1_STRENGTH"].iloc[i] = df_ahp2["TEAM1_STRENGTH"].iloc[i] * 0.542951
        df_ahp2["TEAM1_CUMU_STRENGTH"].iloc[i] = df_ahp2["TEAM1_CUMU_STRENGTH"].iloc[i] * 0.542951
        df_ahp2["WIN_RATE_TEAM1"].iloc[i] = df_ahp2["WIN_RATE_TEAM1"].iloc[i] * 0.542951
        

for i in range(0, 703):
    if df_ahp2["TEAM2"].iloc[i] == "CSK":
        df_ahp2["TEAM2_STRENGTH"].iloc[i] = df_ahp2["TEAM2_STRENGTH"].iloc[i] * 1.521064
        df_ahp2["TEAM2_CUMU_STRENGTH"].iloc[i] = df_ahp2["TEAM2_CUMU_STRENGTH"].iloc[i] * 1.521064
        df_ahp2["WIN_RATE_TEAM2"].iloc[i] = df_ahp2["WIN_RATE_TEAM2"].iloc[i] * 1.521064
    
    elif df_ahp2["TEAM2"].iloc[i] == "MI":
        df_ahp2["TEAM2_STRENGTH"].iloc[i] = df_ahp2["TEAM2_STRENGTH"].iloc[i] * 1.364477
        df_ahp2["TEAM2_CUMU_STRENGTH"].iloc[i] = df_ahp2["TEAM2_CUMU_STRENGTH"].iloc[i] * 1.364477
        df_ahp2["WIN_RATE_TEAM2"].iloc[i] = df_ahp2["WIN_RATE_TEAM2"].iloc[i] * 1.364477
    
    elif df_ahp2["TEAM2"].iloc[i] == "KKR":
        df_ahp2["TEAM2_STRENGTH"].iloc[i] = df_ahp2["TEAM2_STRENGTH"].iloc[i] * 1.147092
        df_ahp2["TEAM2_CUMU_STRENGTH"].iloc[i] = df_ahp2["TEAM2_CUMU_STRENGTH"].iloc[i] * 1.147092
        df_ahp2["WIN_RATE_TEAM2"].iloc[i] = df_ahp2["WIN_RATE_TEAM2"].iloc[i] * 1.147092
    
    elif df_ahp2["TEAM2"].iloc[i] == "RR":
        df_ahp2["TEAM2_STRENGTH"].iloc[i] = df_ahp2["TEAM2_STRENGTH"].iloc[i] * 1.142555
        df_ahp2["TEAM2_CUMU_STRENGTH"].iloc[i] = df_ahp2["TEAM2_CUMU_STRENGTH"].iloc[i] * 1.142555
        df_ahp2["WIN_RATE_TEAM2"].iloc[i] = df_ahp2["WIN_RATE_TEAM2"].iloc[i] * 1.142555
    
    elif df_ahp2["TEAM2"].iloc[i] == "RCB":
        df_ahp2["TEAM2_STRENGTH"].iloc[i] = df_ahp2["TEAM2_STRENGTH"].iloc[i] * 0.898418
        df_ahp2["TEAM2_CUMU_STRENGTH"].iloc[i] = df_ahp2["TEAM2_CUMU_STRENGTH"].iloc[i] * 0.898418
        df_ahp2["WIN_RATE_TEAM2"].iloc[i] = df_ahp2["WIN_RATE_TEAM2"].iloc[i] * 0.898418
    
    elif df_ahp2["TEAM2"].iloc[i] == "KXIP":
        df_ahp2["TEAM2_STRENGTH"].iloc[i] = df_ahp2["TEAM2_STRENGTH"].iloc[i] * 0.844212
        df_ahp2["TEAM2_CUMU_STRENGTH"].iloc[i] = df_ahp2["TEAM2_CUMU_STRENGTH"].iloc[i] * 0.844212
        df_ahp2["WIN_RATE_TEAM2"].iloc[i] = df_ahp2["WIN_RATE_TEAM2"].iloc[i] * 0.844212
    
    elif df_ahp2["TEAM1"].iloc[i] == "SRH":
        df_ahp2["TEAM2_STRENGTH"].iloc[i] = df_ahp2["TEAM2_STRENGTH"].iloc[i] * 0.812388
        df_ahp2["TEAM2_CUMU_STRENGTH"].iloc[i] = df_ahp2["TEAM2_CUMU_STRENGTH"].iloc[i] * 0.812388
        df_ahp2["WIN_RATE_TEAM2"].iloc[i] = df_ahp2["WIN_RATE_TEAM2"].iloc[i] * 0.812388

    elif df_ahp2["TEAM1"].iloc[i] == "DD":
        df_ahp2["TEAM2_STRENGTH"].iloc[i] = df_ahp2["TEAM2_STRENGTH"].iloc[i] * 0.726843
        df_ahp2["TEAM2_CUMU_STRENGTH"].iloc[i] = df_ahp2["TEAM2_CUMU_STRENGTH"].iloc[i] * 0.726843
        df_ahp2["WIN_RATE_TEAM2"].iloc[i] = df_ahp2["WIN_RATE_TEAM2"].iloc[i] * 0.726843
    
    elif df_ahp2["TEAM2"].iloc[i] == "RPS":
        df_ahp2["TEAM2_STRENGTH"].iloc[i] = df_ahp2["TEAM2_STRENGTH"].iloc[i] * 0.542951
        df_ahp2["TEAM2_CUMU_STRENGTH"].iloc[i] = df_ahp2["TEAM2_CUMU_STRENGTH"].iloc[i] * 0.542951
        df_ahp2["WIN_RATE_TEAM2"].iloc[i] = df_ahp2["WIN_RATE_TEAM2"].iloc[i] * 0.542951

# %%
df_ahp2
# Out:
#     TEAM1  TEAM1_MODEL TEAM2  TEAM2_MODEL TOSS_WINNER  TOSS_WINNER_MODEL  \
# 0     KKR            1   RCB            0         RCB                  0
# 1     CSK            1  KXIP            0         CSK                  1
# 2      DD            1    RR            0          RR                  0
# 3     RCB            1    MI            0          MI                  0
# 4     KKR            1   SRH            0         SRH                  0
# ..    ...          ...   ...          ...         ...                ...
# 742   CSK            1  KXIP            0        KXIP                  0
# 743   KKR            1    MI            0          MI                  0
# 744   CSK            1    MI            0         CSK                  1
# 745   SRH            1    DD            0          DD                  0
# 746    DD            1   CSK            0         CSK                  0
#
#      TEAM1_STRENGTH  TEAM1_CUMU_STRENGTH  TEAM2_STRENGTH  TEAM2_CUMU_STRENGTH  \
# ...

# %%
# df_ahp1.to_csv("innings_ahp_mean.csv", index=False)

# %%
X = df[['TEAM1_MODEL', 'TEAM2_MODEL', 
       'TOSS_WINNER_MODEL', 'TEAM1_STRENGTH', 'TEAM1_CUMU_STRENGTH',
       'TEAM2_STRENGTH', 'TEAM2_CUMU_STRENGTH', 'WIN_RATE_TEAM1',
       'WIN_RATE_TEAM2']]
y = df["WINNER_MODEL"]

X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    test_size=0.2,
                                                    random_state=12)

clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
models,predictions = clf.fit(X_train, X_test, y_train, y_test)
models
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 30/30 [00:01<00:00, 28.31it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# CalibratedClassifierCV             0.62               0.62     0.62      0.62
# LinearSVC                          0.62               0.62     0.62      0.62
# LinearDiscriminantAnalysis         0.62               0.62     0.62      0.62
# RidgeClassifierCV                  0.62               0.62     0.62      0.62
# RidgeClassifier                    0.62               0.62     0.62      0.62
# LogisticRegression                 0.62               0.62     0.62      0.62
# NearestCentroid                    0.62               0.62     0.62      0.62
# SVC                                0.60               0.61     0.61      0.60
# GaussianNB                         0.58               0.59     0.59      0.57
# ...
