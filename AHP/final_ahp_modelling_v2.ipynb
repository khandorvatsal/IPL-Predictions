# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
from sklearn.model_selection import train_test_split

import lazypredict
from lazypredict.Supervised import LazyClassifier
# Out:
# C:\Users\khand\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:144: FutureWarning: The sklearn.utils.testing module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.utils. Anything that cannot be imported from sklearn.utils is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
df = pd.read_csv("no_innings_ahp_mean.csv")
df
# Out:
#     TEAM1  TEAM1_MODEL TEAM2  TEAM2_MODEL TOSS_WINNER  TOSS_WINNER_MODEL  \
# 0     KKR            1   RCB            0         RCB                  0
# 1     CSK            1  KXIP            0         CSK                  1
# 2      DD            1    RR            0          RR                  0
# 3     RCB            1    MI            0          MI                  0
# 4     KKR            1   SRH            0         SRH                  0
# ..    ...          ...   ...          ...         ...                ...
# 698   CSK            1  KXIP            0        KXIP                  0
# 699   KKR            1    MI            0          MI                  0
# 700   CSK            1    MI            0         CSK                  1
# 701   SRH            1    DD            0          DD                  0
# 702    DD            1   CSK            0         CSK                  0
#
#      TEAM1_STRENGTH  TEAM1_CUMU_STRENGTH  TEAM2_STRENGTH  TEAM2_CUMU_STRENGTH  \
# ...

# %%
X = df[['TEAM1_MODEL', 'TEAM2_MODEL', 
       'TOSS_WINNER_MODEL', 'TEAM1_STRENGTH', 'TEAM1_CUMU_STRENGTH',
       'TEAM2_STRENGTH', 'TEAM2_CUMU_STRENGTH', 'WIN_RATE_TEAM1',
       'WIN_RATE_TEAM2']]
y = df["WINNER_MODEL"]

X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    test_size=0.2,
                                                    random_state=12)

clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
models,predictions = clf.fit(X_train, X_test, y_train, y_test)
models
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 30/30 [00:01<00:00, 25.06it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# CalibratedClassifierCV             0.64               0.64     0.64      0.64
# SVC                                0.63               0.64     0.64      0.63
# LGBMClassifier                     0.63               0.63     0.63      0.63
# RandomForestClassifier             0.62               0.63     0.63      0.62
# LinearDiscriminantAnalysis         0.61               0.62     0.62      0.61
# RidgeClassifier                    0.61               0.62     0.62      0.61
# LogisticRegression                 0.61               0.62     0.62      0.61
# LinearSVC                          0.61               0.62     0.62      0.61
# RidgeClassifierCV                  0.61               0.61     0.61      0.61
# ...

# %% [markdown]
# ### We'll try the best 10 models which have accuracy greater than 0.6

# %%
from sklearn.calibration import CalibratedClassifierCV
train_list = []
test_list = []

for i in range(10, 100, 1):
    model = CalibratedClassifierCV(cv = i)
    model.fit(X_train, y_train)
    train_list.append(model.score(X_train, y_train))
    test_list.append(model.score(X_test, y_test))

# %%
train_list
# Out:
# [0.5320284697508897,
#  0.5355871886120996,
#  0.4928825622775801,
#  0.5516014234875445,
#  0.5124555160142349,
#  0.5551601423487544,
#  0.5355871886120996,
#  0.5658362989323843,
#  0.5409252669039146,
#  0.5444839857651246,
#  0.5302491103202847,
#  0.5338078291814946,
#  0.5391459074733096,
#  0.5640569395017794,
#  0.5320284697508897,
#  0.5124555160142349,
#  0.5195729537366548,
#  0.5177935943060499,
#  0.5142348754448398,
#  0.5355871886120996,
#  0.4786476868327402,
#  0.5124555160142349,
#  0.5444839857651246,
#  0.5462633451957295,
#  0.5,
#  0.5231316725978647,
#  0.5213523131672598,
#  0.5427046263345195,
#  0.5355871886120996,
#  0.5409252669039146,
#  0.5231316725978647,
#  0.5195729537366548,
#  0.5427046263345195,
#  0.5551601423487544,
#  0.5551601423487544,
#  0.5604982206405694,
#  0.5676156583629893,
#  0.5516014234875445,
#  0.5266903914590747,
#  0.5088967971530249,
#  0.5249110320284698,
#  0.5249110320284698,
#  0.5195729537366548,
#  0.5249110320284698,
# ...

# %%
test_list
# Out:
# [0.5106382978723404,
#  0.5602836879432624,
#  0.574468085106383,
#  0.6028368794326241,
#  0.49645390070921985,
#  0.6170212765957447,
#  0.5602836879432624,
#  0.6099290780141844,
#  0.5602836879432624,
#  0.5390070921985816,
#  0.5531914893617021,
#  0.574468085106383,
#  0.5673758865248227,
#  0.6170212765957447,
#  0.5390070921985816,
#  0.48226950354609927,
#  0.5035460992907801,
#  0.46808510638297873,
#  0.48226950354609927,
#  0.5602836879432624,
#  0.48226950354609927,
#  0.5177304964539007,
#  0.5886524822695035,
#  0.5886524822695035,
#  0.5673758865248227,
#  0.574468085106383,
#  0.5106382978723404,
#  0.5177304964539007,
#  0.5460992907801419,
#  0.5602836879432624,
#  0.49645390070921985,
#  0.475177304964539,
#  0.5602836879432624,
#  0.6170212765957447,
#  0.5602836879432624,
#  0.5815602836879432,
#  0.6099290780141844,
#  0.5602836879432624,
#  0.5673758865248227,
#  0.5531914893617021,
#  0.5815602836879432,
#  0.5673758865248227,
#  0.5673758865248227,
# ...

# %%
max(test_list)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-beb19d8cef91> in <module>
# ----> 1 max(test_list).index
#
# AttributeError: 'numpy.float64' object has no attribute 'index'

# %%
train_list = []
test_list = []

for i in range(100, 200, 1):
    model = CalibratedClassifierCV(cv = i)
    model.fit(X_train, y_tra
              in)
    train_list.append(model.score(X_train, y_train))
    test_list.append(model.score(X_test, y_test))

# %%
train_list
# Out:
# [0.5498220640569395,
#  0.5249110320284698,
#  0.5249110320284698,
#  0.5409252669039146,
#  0.5177935943060499,
#  0.5231316725978647,
#  0.5391459074733096,
#  0.5480427046263345,
#  0.5373665480427047,
#  0.5729537366548043,
#  0.5516014234875445,
#  0.5409252669039146,
#  0.5160142348754448,
#  0.5516014234875445,
#  0.5444839857651246,
#  0.5569395017793595,
#  0.5658362989323843,
#  0.5266903914590747,
#  0.5427046263345195,
#  0.5231316725978647,
#  0.50355871886121,
#  0.5071174377224199,
#  0.5142348754448398,
#  0.5124555160142349,
#  0.498220640569395,
#  0.5231316725978647,
#  0.5124555160142349,
#  0.5088967971530249,
#  0.5391459074733096,
#  0.5213523131672598,
#  0.5160142348754448,
#  0.5622775800711743,
#  0.5516014234875445,
#  0.5516014234875445,
#  0.5604982206405694,
#  0.5462633451957295,
#  0.5516014234875445,
#  0.5391459074733096,
#  0.5427046263345195,
#  0.5444839857651246,
#  0.5533807829181495,
#  0.5320284697508897,
#  0.5177935943060499,
# ...

# %%
test_list
# Out:
# [0.6170212765957447,
#  0.49645390070921985,
#  0.524822695035461,
#  0.574468085106383,
#  0.5177304964539007,
#  0.524822695035461,
#  0.524822695035461,
#  0.5886524822695035,
#  0.5886524822695035,
#  0.624113475177305,
#  0.5957446808510638,
#  0.574468085106383,
#  0.46808510638297873,
#  0.5815602836879432,
#  0.524822695035461,
#  0.5460992907801419,
#  0.6028368794326241,
#  0.5177304964539007,
#  0.5957446808510638,
#  0.5390070921985816,
#  0.524822695035461,
#  0.524822695035461,
#  0.48936170212765956,
#  0.5390070921985816,
#  0.5177304964539007,
#  0.524822695035461,
#  0.5106382978723404,
#  0.5106382978723404,
#  0.5319148936170213,
#  0.5319148936170213,
#  0.5390070921985816,
#  0.524822695035461,
#  0.5390070921985816,
#  0.5390070921985816,
#  0.524822695035461,
#  0.5319148936170213,
#  0.524822695035461,
#  0.5035460992907801,
#  0.5035460992907801,
#  0.49645390070921985,
#  0.5390070921985816,
#  0.45390070921985815,
#  0.5106382978723404,
# ...

# %%
max(test_list)
# Out:
# 0.6453900709219859
