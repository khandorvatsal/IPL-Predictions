# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import glob

path = r'C:\Users\khand\Desktop\IPL Practice\bat' # use your path
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

dataset = pd.concat(li, axis=0, ignore_index=True)

# %%
dataset
# Out:
#               Player   Mat  Inns   NO   Runs   HS    Ave     BF      SR  100  \
# 0           MS Dhoni  15.0  12.0  7.0  416.0  84*   83.2  309.0  134.62  0.0
# 1       F du Plessis  12.0  12.0  1.0  396.0   96     36  321.0  123.36  0.0
# 2          RA Jadeja  16.0   9.0  6.0  106.0  31*  35.33   88.0  120.45  0.0
# 3            M Vijay   2.0   2.0  0.0   64.0   38     32   61.0  104.91  0.0
# 4         MJ Santner   4.0   2.0  1.0   32.0   22     32   23.0  139.13  0.0
# ..               ...   ...   ...  ...    ...  ...    ...    ...     ...  ...
# 410  Shakib Al Hasan   3.0   1.0  0.0    9.0    9      9   10.0      90  0.0
# 411          RK Bhui   1.0   1.0  0.0    7.0    7      7   12.0   58.33  0.0
# 412      Rashid Khan  15.0   8.0  3.0   34.0  17*    6.8   23.0  147.82  0.0
# 413  Abhishek Sharma   3.0   3.0  1.0    9.0   5*    4.5    9.0     100  0.0
# 414          B Kumar  15.0   5.0  2.0   12.0   7*      4   19.0   63.15  0.0
#
#       50    0    4s    6s
# ...

# %%
df_tmp = dataset

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 415 entries, 0 to 414
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Player  409 non-null    object
#  1   Mat     409 non-null    float64
#  2   Inns    409 non-null    float64
#  3   NO      409 non-null    float64
#  4   Runs    409 non-null    float64
#  5   HS      409 non-null    object
#  6   Ave     409 non-null    object
#  7   BF      409 non-null    float64
#  8   SR      409 non-null    object
#  9   100     409 non-null    float64
#  10  50      409 non-null    float64
#  11  0       409 non-null    float64
#  12  4s      409 non-null    float64
#  13  6s      409 non-null    float64
# dtypes: float64(10), object(4)
# memory usage: 45.5+ KB

# %%
dataset.replace("-", np.nan, inplace=True)
dataset
# Out:
#               Player   Mat  Inns   NO   Runs   HS    Ave     BF      SR  100  \
# 0           MS Dhoni  15.0  12.0  7.0  416.0  84*   83.2  309.0  134.62  0.0
# 1       F du Plessis  12.0  12.0  1.0  396.0   96     36  321.0  123.36  0.0
# 2          RA Jadeja  16.0   9.0  6.0  106.0  31*  35.33   88.0  120.45  0.0
# 3            M Vijay   2.0   2.0  0.0   64.0   38     32   61.0  104.91  0.0
# 4         MJ Santner   4.0   2.0  1.0   32.0   22     32   23.0  139.13  0.0
# ..               ...   ...   ...  ...    ...  ...    ...    ...     ...  ...
# 410  Shakib Al Hasan   3.0   1.0  0.0    9.0    9      9   10.0      90  0.0
# 411          RK Bhui   1.0   1.0  0.0    7.0    7      7   12.0   58.33  0.0
# 412      Rashid Khan  15.0   8.0  3.0   34.0  17*    6.8   23.0  147.82  0.0
# 413  Abhishek Sharma   3.0   3.0  1.0    9.0   5*    4.5    9.0     100  0.0
# 414          B Kumar  15.0   5.0  2.0   12.0   7*      4   19.0   63.15  0.0
#
#       50    0    4s    6s
# ...

# %%
dataset["HS"] = dataset["HS"].str.replace('*','')
dataset
# Out:
#               Player   Mat  Inns   NO   Runs  HS    Ave     BF      SR  100  \
# 0           MS Dhoni  15.0  12.0  7.0  416.0  84   83.2  309.0  134.62  0.0
# 1       F du Plessis  12.0  12.0  1.0  396.0  96     36  321.0  123.36  0.0
# 2          RA Jadeja  16.0   9.0  6.0  106.0  31  35.33   88.0  120.45  0.0
# 3            M Vijay   2.0   2.0  0.0   64.0  38     32   61.0  104.91  0.0
# 4         MJ Santner   4.0   2.0  1.0   32.0  22     32   23.0  139.13  0.0
# ..               ...   ...   ...  ...    ...  ..    ...    ...     ...  ...
# 410  Shakib Al Hasan   3.0   1.0  0.0    9.0   9      9   10.0      90  0.0
# 411          RK Bhui   1.0   1.0  0.0    7.0   7      7   12.0   58.33  0.0
# 412      Rashid Khan  15.0   8.0  3.0   34.0  17    6.8   23.0  147.82  0.0
# 413  Abhishek Sharma   3.0   3.0  1.0    9.0   5    4.5    9.0     100  0.0
# 414          B Kumar  15.0   5.0  2.0   12.0   7      4   19.0   63.15  0.0
#
#       50    0    4s    6s
# 0    3.0  0.0  22.0  23.0
# ...

# %%
dataset.isna().sum()
# Out:
# Player     6
# Mat        6
# Inns       6
# NO         6
# Runs       6
# HS         6
# Ave       48
# BF         6
# SR         9
# 100        6
# 50         6
# 0          6
# 4s         6
# 6s         6
# dtype: int64

# %%
dataset.fillna(0, inplace=True)

# %%
dataset.isna().sum()
# Out:
# Player    0
# Mat       0
# Inns      0
# NO        0
# Runs      0
# HS        0
# Ave       0
# BF        0
# SR        0
# 100       0
# 50        0
# 0         0
# 4s        0
# 6s        0
# dtype: int64

# %%
dataset["HS"] = dataset["HS"].astype(int)
dataset["Ave"] = dataset["Ave"].astype(float)
dataset["SR"] = dataset["SR"].astype(float)

# %%
dataset.drop("Player", axis=1, inplace=True)

# %%
dataset.corr()
# Out:
#            Mat      Inns        NO      Runs        HS       Ave        BF  \
# Mat   1.000000  0.784754  0.501242  0.623054  0.526117  0.430675  0.627382
# Inns  0.784754  1.000000  0.433227  0.879607  0.810760  0.648361  0.888888
# NO    0.501242  0.433227  1.000000  0.267247  0.216339  0.426780  0.254148
# Runs  0.623054  0.879607  0.267247  1.000000  0.888093  0.762669  0.985906
# HS    0.526117  0.810760  0.216339  0.888093  1.000000  0.807512  0.870553
# Ave   0.430675  0.648361  0.426780  0.762669  0.807512  1.000000  0.739614
# BF    0.627382  0.888888  0.254148  0.985906  0.870553  0.739614  1.000000
# SR    0.306125  0.436270  0.258486  0.417057  0.523721  0.513937  0.365759
# 100   0.160835  0.231087  0.066544  0.453978  0.359472  0.326821  0.413229
# 50    0.465557  0.680519  0.126556  0.888318  0.778538  0.669895  0.878032
# 0     0.297768  0.308622 -0.003649  0.172272  0.179171  0.011040  0.178394
# ...

# %%
import seaborn as sns
# %matplotlib inline
fig, ax = plt.subplots(figsize=(12, 10))
ax = sns.heatmap(dataset.corr(), annot=True)

# %%
# grouped_df = frame.groupby("Player").sum()
# grouped_df.head()

# %%
dataset.head()
# Out:
#     Mat  Inns   NO   Runs  HS    Ave     BF      SR  100   50    0    4s    6s
# 0  15.0  12.0  7.0  416.0  84  83.20  309.0  134.62  0.0  3.0  0.0  22.0  23.0
# 1  12.0  12.0  1.0  396.0  96  36.00  321.0  123.36  0.0  3.0  0.0  36.0  15.0
# 2  16.0   9.0  6.0  106.0  31  35.33   88.0  120.45  0.0  0.0  0.0   7.0   4.0
# 3   2.0   2.0  0.0   64.0  38  32.00   61.0  104.91  0.0  0.0  0.0   6.0   1.0
# 4   4.0   2.0  1.0   32.0  22  32.00   23.0  139.13  0.0  0.0  0.0   0.0   3.0

# %%
# X = dataset.drop("Runs", axis=1)
# y = dataset["Runs"]

# %%
# from sklearn.model_selection import train_test_split
# X_train, X_test, y_train, y_test = train_test_split(X,
#                                                     y,
#                                                     test_size=0.2,
#                                                     random_state=12)

# %%
# from sklearn.linear_model import LinearRegression
# model = LinearRegression()
# model.fit(X_train, y_train)

# %%
# model.score(X_train, y_train)

# %%
# model.intercept_

# %%
# model.coef_

# %%
# model.score(X_test, y_test)

# %%
# Droppig Inns cause it is directly calculating by (average runs * Inns)

# %%
X = dataset.iloc[:, [1, 5, 7, 8, 9]].values
y = dataset["Runs"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    test_size=0.2,
                                                    random_state=12)

# %%
X_test
# Out:
# array([[  8.  ,  13.33,  88.88,   0.  ,   0.  ],
#        [ 16.  ,  35.26, 132.91,   0.  ,   4.  ],
#        [ 13.  ,  45.  , 122.44,   0.  ,   6.  ],
#        [ 17.  ,  23.5 ,  93.06,   0.  ,   1.  ],
#        [ 14.  ,  46.63, 175.08,   1.  ,   2.  ],
#        [ 12.  ,  36.  , 123.36,   0.  ,   3.  ],
#        [  3.  ,  40.66, 158.44,   0.  ,   2.  ],
#        [  1.  ,   6.  ,  85.71,   0.  ,   0.  ],
#        [ 12.  ,  30.36, 120.14,   0.  ,   2.  ],
#        [ 14.  ,  17.23, 172.3 ,   0.  ,   1.  ],
#        [  4.  ,  13.75, 117.02,   0.  ,   0.  ],
#        [  4.  ,   1.  ,  33.33,   0.  ,   0.  ],
#        [ 13.  ,  37.08, 136.08,   1.  ,   3.  ],
#        [  4.  ,   2.25,  75.  ,   0.  ,   0.  ],
#        [  1.  ,   5.  ,  62.5 ,   0.  ,   0.  ],
#        [  9.  ,  39.5 , 191.12,   0.  ,   1.  ],
#        [  7.  ,  30.66, 109.52,   0.  ,   0.  ],
#        [  5.  ,  33.5 , 167.5 ,   0.  ,   0.  ],
#        [ 16.  ,  23.78, 121.97,   0.  ,   3.  ],
# ...

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train[:, :] = sc.fit_transform(X_train[:, :])
X_test[:, :] = sc.transform(X_test[:, :])

# %%
X_test
# Out:
# array([[ 0.33070623, -0.30080553, -0.50363836, -0.14416883, -0.54354604],
#        [ 1.97249268,  1.07498466,  0.37292469, -0.14416883,  2.55443312],
#        [ 1.35682276,  1.68602873,  0.16448465, -0.14416883,  4.1034227 ],
#        [ 2.17771599,  0.33721482, -0.42042161, -0.14416883,  0.23094875],
#        [ 1.56204607,  1.78828764,  1.21245828,  3.53768127,  1.00544354],
#        [ 1.15159946,  1.12140895,  0.1828003 , -0.14416883,  1.77993833],
#        [-0.6954103 ,  1.41375652,  0.88118394, -0.14416883,  1.00544354],
#        [-1.10585691, -0.76065697, -0.56674772, -0.14416883, -0.54354604],
#        [ 1.15159946,  0.76758056,  0.11869553, -0.14416883,  1.00544354],
#        [ 1.56204607, -0.05613696,  1.15711317, -0.14416883,  0.23094875],
#        [-0.49018699, -0.27445661,  0.05658159, -0.14416883, -0.54354604],
#        [-0.49018699, -1.07433463, -1.60954519, -0.14416883, -0.54354604],
#        [ 1.35682276,  1.18916332,  0.43603405,  3.53768127,  1.77993833],
# ...

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
model.score(X_train, y_train)
# Out:
# 0.9533774785493146

# %%
model.score(X_test, y_test)
# Out:
# 0.967989928167121

# %%
y_preds = model.predict(X_test)

# %%
y_preds = np.array(y_preds)
y_test = np.array(y_test)

# %%
np.set_printoptions(precision=2)
print(np.concatenate((y_preds.reshape(len(y_preds),1), y_test.reshape(len(y_test),1)),1))
# Out:
# [[109.61  40.  ]
#  [472.14 529.  ]
#  [538.05 540.  ]
#  [319.49 282.  ]
#  [435.74 513.  ]
#  [355.98 396.  ]
#  [162.89 122.  ]
#  [-12.62   6.  ]
#  [297.74 334.  ]
#  [263.62 224.  ]
#  [ 44.99  55.  ]
#  [ 30.53   1.  ]
#  [460.52 445.  ]
#  [ 31.97   9.  ]
#  [-13.76   5.  ]
#  [207.4  237.  ]
#  [112.93  92.  ]
#  [ 83.62  67.  ]
#  [407.29 333.  ]
#  [ 23.34  27.  ]
#  [128.66 126.  ]
#  [ 94.2   57.  ]
#  [167.92 133.  ]
#  [274.   291.  ]
#  [ 71.24  49.  ]
#  [ 13.1    0.  ]
#  [101.97  98.  ]
#  [-19.46   0.  ]
#  [203.64 195.  ]
#  [186.74 211.  ]
#  [ 26.14  23.  ]
#  [103.59  32.  ]
#  [-18.29   1.  ]
#  [218.45 255.  ]
#  [ 82.81  16.  ]
#  [ 18.82  15.  ]
#  [501.84 489.  ]
#  [ -0.88   2.  ]
#  [ 59.51  61.  ]
#  [ 19.55  17.  ]
#  [ 65.2   86.  ]
#  [409.31 416.  ]
#  [175.61 169.  ]
#  [ 17.81  37.  ]
#  [-19.34   5.  ]
#  [ 35.67  22.  ]
#  [  0.83   7.  ]
#  [682.8  687.  ]
#  [429.61 490.  ]
#  [-35.74   0.  ]
#  [ 26.69  12.  ]
#  [148.48 153.  ]
# ...
