# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("final_data_with_individual features.csv")
df
# Out:
#      Unnamed: 0  Unnamed: 0.1     ID  SEASON           CITY CITY_Corrrected  \
# 0             0             0     60    2008      Bangalore             RCB
# 1             1             1     61    2008     Chandigarh            KXIP
# 2             2             2     62    2008          Delhi              DD
# 3             3             3     63    2008         Mumbai              MI
# 4             4             4     64    2008        Kolkata             KKR
# ..          ...           ...    ...     ...            ...             ...
# 742         742           742  11346    2019         Mohali            KXIP
# 743         743           743  11347    2019         Mumbai              MI
# 744         744           744  11412    2019        Chennai             CSK
# 745         745           745  11413    2019  Visakhapatnam   Visakhapatnam
# 746         746           746  11414    2019  Visakhapatnam   Visakhapatnam
#
# ...

# %%
df.dropna().drop(["Unnamed: 0", "Unnamed: 0.1", "ID", "TEAM1", "TEAM2", "CITY", "TOSS_DECISION", "WIN_BY_RUNS", "CITY_Corrrected", "TOSS_WINNER", "WINNER"], axis=1, inplace=True)
df
# Out:
# C:\Users\khand\anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#      Unnamed: 0  Unnamed: 0.1     ID  SEASON           CITY CITY_Corrrected  \
# 0             0             0     60    2008      Bangalore             RCB
# 1             1             1     61    2008     Chandigarh            KXIP
# 2             2             2     62    2008          Delhi              DD
# 3             3             3     63    2008         Mumbai              MI
# 4             4             4     64    2008        Kolkata             KKR
# ..          ...           ...    ...     ...            ...             ...
# 742         742           742  11346    2019         Mohali            KXIP
# ...

# %%
df.drop(["Unnamed: 0", "Unnamed: 0.1", "ID", "TEAM1", "TEAM2", "CITY", "TOSS_DECISION", "WIN_BY_RUNS", "CITY_Corrrected", "TOSS_WINNER", "WINNER"], axis=1, inplace=True)
df
# Out:
#      SEASON  TEAM1_MODEL  TEAM2_MODEL  TEAM1_RunsperOver  TEAM1_RunsperWicket  \
# 0      2008            1            0                NaN                  NaN
# 1      2008            1            0                NaN                  NaN
# 2      2008            1            0                NaN                  NaN
# 3      2008            1            0                NaN                  NaN
# 4      2008            1            0                NaN                  NaN
# ..      ...          ...          ...                ...                  ...
# 742    2019            1            0           8.578696            35.038961
# 743    2019            1            0           8.536977            25.776699
# 744    2019            1            0           8.578696            35.038961
# 745    2019            1            0           7.796102            26.530612
# 746    2019            1            0           8.720930            30.000000
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 747 entries, 0 to 746
# Data columns (total 54 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   SEASON                              747 non-null    int64
#  1   TEAM1_MODEL                         747 non-null    int64
#  2   TEAM2_MODEL                         747 non-null    int64
#  3   TEAM1_RunsperOver                   670 non-null    float64
#  4   TEAM1_RunsperWicket                 670 non-null    float64
#  5   TEAM1_BattingIndex                  670 non-null    float64
#  6   TEAM1_RunsconcededperOver           670 non-null    float64
#  7   TEAM1_RunsconcededperWicket         670 non-null    float64
#  8   TEAM1_BowlingIndex                  670 non-null    float64
#  9   TEAM1_BattingWicketRate             670 non-null    float64
#  10  TEAM1_BowlingWicketRate             670 non-null    float64
# ...

# %%
df['RESULT'] = df['RESULT'].map({'normal': 1, 'tie': 0})
df
# Out:
#      SEASON  TEAM1_MODEL  TEAM2_MODEL  TEAM1_RunsperOver  TEAM1_RunsperWicket  \
# 0      2008            1            0                NaN                  NaN
# 1      2008            1            0                NaN                  NaN
# 2      2008            1            0                NaN                  NaN
# 3      2008            1            0                NaN                  NaN
# 4      2008            1            0                NaN                  NaN
# ..      ...          ...          ...                ...                  ...
# 742    2019            1            0           8.578696            35.038961
# 743    2019            1            0           8.536977            25.776699
# 744    2019            1            0           8.578696            35.038961
# 745    2019            1            0           7.796102            26.530612
# 746    2019            1            0           8.720930            30.000000
#
# ...

# %%
df.dropna(axis=0, inplace=True)
df
# Out:
#      SEASON  TEAM1_MODEL  TEAM2_MODEL  TEAM1_RunsperOver  TEAM1_RunsperWicket  \
# 58     2009            1            0           7.542744            24.012658
# 59     2009            1            0           6.971963            17.594340
# 60     2009            1            0           8.337292            29.620253
# 61     2009            1            0           7.199201            20.465909
# 62     2009            1            0           7.874584            29.936709
# ..      ...          ...          ...                ...                  ...
# 742    2019            1            0           8.578696            35.038961
# 743    2019            1            0           8.536977            25.776699
# 744    2019            1            0           8.578696            35.038961
# 745    2019            1            0           7.796102            26.530612
# 746    2019            1            0           8.720930            30.000000
#
# ...

# %%
X = df.drop("WINNER_MODEL", axis=1)
y = df["WINNER_MODEL"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    test_size=0.2,
                                                    random_state=12)

# %%
# pip install mlxtend

# %%
from mlxtend.feature_selection import ExhaustiveFeatureSelector as EFS
from sklearn.ensemble import RandomForestClassifier

# %%
efs1 = EFS(RandomForestClassifier(n_estimators=100, max_depth=5,random_state=0), 
           min_features=1,
           max_features=46,
           scoring='accuracy',
           print_progress=True,
           cv=None,
          n_jobs = -1).fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-f15d5016fd30> in <module>
#       5            print_progress=True,
#       6            cv=None,
# ----> 7           n_jobs = -1).fit(X_train, y_train)
#
# ~\anaconda3\lib\site-packages\mlxtend\feature_selection\exhaustive_feature_selector.py in fit(self, X, y, custom_feature_names, groups, **fit_params)
#     274         work = enumerate(parallel(delayed(_calc_score)
#     275                                   (self, X_, y, c, groups=groups, **fit_params)
# --> 276                                   for c in candidates))
#     277
#     278         try:
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1015
#    1016             with self._backend.retrieval_context():
# -> 1017                 self.retrieve()
# ...
